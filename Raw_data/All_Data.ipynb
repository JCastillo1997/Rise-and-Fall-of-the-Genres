# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1940 = pd.read_csv('data_1940.csv') 
df_1950 = pd.read_csv('data_1950.csv') 
df_1960 = pd.read_csv('data_1960.csv') 
df_1970 = pd.read_csv('data_1970.csv') 
df_1980 = pd.read_csv('data_1980.csv') 
df_1990 = pd.read_csv('data_1990.csv') 
df_2000 = pd.read_csv('data_2000.csv') 
df_2010 = pd.read_csv('data_2010.csv')

# %%
df_total= pd.concat([df_1940,df_1950,df_1960,df_1970,df_1980,df_1990,df_2000,df_2010],axis=0)

df_total
# Out:
#                                         cancion       cantante   año  \
# 0                        I'll Never Smile Again   Tommy Dorsey  1990
# 1                 Only Forever - Single Version    Bing Crosby  1993
# 2                                       Frenesi     Artie Shaw  1938
# 3   Song of the Volga Boatmen - Remastered 2002   Glenn Miller  2005
# 4                                       Amapola   Jimmy Dorsey  2010
# ..                                          ...            ...   ...
# 95               Outside (feat. Ellie Goulding)  Calvin Harris  2014
# 96                             Story of My Life  One Direction  2013
# 97                                      Beggin'       Måneskin  2017
# 98                                      Riptide      Vance Joy  2014
# 99                            Thinking out Loud     Ed Sheeran  2014
#
#     duracion_minutos                                     album  explicito
# ...

# %%
df_total_2=df_total.sort_values(by=['año'],ascending=True,)
df_total_2
# Out:
#                                               cancion  \
# 24                                  You'll Never Know
# 9          Piano Concerto in B-Flat (Tonight We Love)
# 2                                             Frenesi
# 42  Sentimental Journey (with Les Brown & His Orch...
# 41          My Dreams Are Getting Better All the Time
# ..                                                ...
# 29                                            Sh-Boom
# 39                                        You Send Me
# 50                         Funkytown - Single Version
# 40                         Maniac - From "Flashdance"
# 58                                          Teardrops
#
#                          cantante   año  duracion_minutos  \
# 24                    Dick Haymes  1936          2.754217
# 9   Freddy Martin & His Orchestra  1937          3.231767
# 2                      Artie Shaw  1938          3.040217
# 42                      Doris Day  1945          3.214883
# ...

# %%
plt.plot(df_total_2['año'], df_total_2['duracion_minutos'], color='green')


plt.xlabel('Año')
plt.ylabel('Duración en Minutos')
plt.title('Relación entre Duración y Año')


plt.show()

# %%
plt.plot(df_total_2['año'], df_total_2['explicito'], color='green')


plt.xlabel('Año',color='white')
plt.ylabel('Duración en Minutos',color='white')
plt.title('Relación entre Duración y Año',color='white')


plt.show()

# %%
df_total_2.duracion_minutos.describe()
# Out:
# count    786.000000
# mean       3.617419
# std        1.115372
# min        1.858917
# 25%        2.914433
# 50%        3.519775
# 75%        4.171825
# max       21.538217
# Name: duracion_minutos, dtype: float64

# %%
df_total_3=df_total_2.sort_values(by=['duracion_minutos'],ascending=True)
df_total_3
# Out:
#                                               cancion         cantante   año  \
# 6                                 Great Balls Of Fire  Jerry Lee Lewis  1961
# 82                                         The Letter     The Box Tops  1967
# 94                         Yakety Yak - 2007 Remaster     The Coasters  2007
# 1                                  We Belong Together   Ritchie Valens  1959
# 68                                       All Shook Up    Elvis Presley  1958
# ..                                                ...              ...   ...
# 72                         Hey Jude - Remastered 2015      The Beatles  2000
# 1                                         Blue Monday        New Order  1987
# 0   White Wedding (Pts. 1 & 2) - Shotgun Mix / Rem...       Billy Idol  1985
# 0                                       November Rain    Guns N' Roses  1991
# 71                                          Get Ready       Rare Earth  1969
#
# ...
