# %%
import pandas as pd

# %%
url='https://shouvikmani.github.io/Million-Song-Dataset-Visualization/index.html'
df_production=pd.read_html(url)[0]

# %%
df_production.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_production
# Out:
#           Genre  Alternative  Blues  Country  Dance  Disco  Electronic  Folk  \
# 0   alternative        11821    800      547   1955    452        2337  1463
# 1         blues          800   6194      472    615    175         251   566
# 2       country          547    472     4315    354     62          97   838
# 3         dance         1955    615      354   8229   1140        3430   463
# 4         disco          452    175       62   1140   2030         762   126
# 5    electronic         2337    251       97   3430    762        8741   426
# 6          folk         1463    566      838    463    126         426  4927
# 7         indie         5178    491      449   1039    285        1290  1172
# 8          jazz         1291   1472      196   1595    486        2116   565
# 9         latin          255     62       41    397     85         175   194
# 10        metal         2220    299       87    581    155         764   601
# ...
