# %%
import pandas as pd

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\casti\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\casti\anaconda3\lib\site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\casti\anaconda3\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\casti\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\casti\anaconda3\lib\site-packages (from spotipy) (1.26.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\casti\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\casti\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\casti\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2023.5.7)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %%
def create_playlist_dataframe(playlist_id):
    # Configuración de la autenticación de la API de Spotify
    client_credentials_manager = SpotifyClientCredentials(client_id="8aaea3fe61404b23aa07c9f760df3985", client_secret="e6670aad9bc94f1ba66f382abe39394c")
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

    # Obtener la información de la playlist
    playlist = sp.playlist(playlist_id)


    # Procesar la información para crear el DataFrame
    data = {
        'cancion':[],
        'cantante': [],
        'año': [],
        'duracion_minutos': [],
        'album': [],
        'explicito': [],
    }

    for track in playlist['tracks']['items']:
        data['cancion'].append(track['track']['name'])
        data['cantante'].append(track['track']['artists'][0]['name'])
        data['año'].append(track['track']['album']['release_date'][:4])
        data['duracion_minutos'].append(track['track']['duration_ms'] / 60000)
        data['album'].append(track['track']['album']['name'])
        data['explicito'].append(track['track']['explicit'])

    df = pd.DataFrame(data)
    return df

# %%
create_playlist_dataframe('37i9dQZEVXbNFJfN1Vw8d9')
# Out:
#                                               cancion          cantante   año  \
# 0            Young Miko: Bzrp Music Sessions, Vol. 58          Bizarrap  2024
# 1                                         Manos Rotas       DELLAFUENTE  2023
# 2                                                LUNA              Feid  2023
# 3                                               M.A.I            Milo j  2023
# 4                               No Te Quieren Conmigo        Gaby Music  2023
# 5                                            Casanova          Soolking  2023
# 6                       Una Foto Remix (feat. Emilia)            Mesita  2024
# 7                                            LA FALDA       Myke Towers  2023
# 8                                            Columbia           Quevedo  2023
# 9                                        Hey Lil Mama    Eladio Carrion  2024
# 10                                        PERRO NEGRO         Bad Bunny  2023
# 11                                    La_Original.mp3            Emilia  2023
# 12                                           MODELITO              Mora  2022
# 13                                            DILUVIO    Rauw Alejandro  2023
# 14                                            LA CAPI       Myke Towers  2023
# 15                                              A 300          JC Reyes  2023
# 16                               COSAS QUE NO TE DIJE             Saiko  2021
# 17                                   Perdió Este Culo          Bad Gyal  2024
# 18                                        Si No Estás    iñigo quintero  2022
# 19                      Narcotics (with Bryant Myers)             Dei V  2023
# 20                                            El Malo    Eladio Carrion  2024
# 21                                        Madrid City          Ana Mena  2023
# 22                                              REINA              Mora  2023
# 23                                    Quien Es Dei V?             Dei V  2023
# 24                                              QLONA           KAROL G  2023
# 25                                                 OA          Anuel AA  2023
# 26                                    POLARIS - Remix             Saiko  2023
# 27                                         BABY HELLO    Rauw Alejandro  2023
# 28  Japoni (feat. Camin, Moncho Chavea, Jthyago & ...     Oscar el Ruso  2024
# 29                                             Buenas           Quevedo  2023
# 30                                   NO PIENSO LLAMAR      Soge Culebra  2023
# 31                                     SI SABE FERXXO            Blessd  2024
# 32                                               LALA       Myke Towers  2023
# 33                                         La Bachata     Manuel Turizo  2023
# 34                                          VAGABUNDO   Sebastian Yatra  2023
# 35                                            Holanda            Jhayco  2023
# 36                                               SEDA         Bad Bunny  2023
# 37                                     ASI ES LA VIDA  Enrique Iglesias  2023
# 38                                           El Mambo       Kiko Rivera  2023
# 39                                               SEYA              GIMS  2022
# 40                                          X'CLUSIVO             Gonzy  2023
# 41                                      lady madrizZz              céro  2023
# 42                                           El Cielo     Sky Rompiendo  2023
# 43                                 Corazón Roto pt. 3             Brray  2023
# 44                                             Alucin  Eugenio Esquivel  2023
# 45                                     LUCES DE TECNO              Feid  2023
# 46                                       No_Se_Ve.mp3            Emilia  2023
# 47                                    Los del Espacio        LIT killah  2023
# 48                                      Extasisssssss             Saiko  2023
# 49                    No Estuviste En Lo Malo - REMIX             Morad  2023
#
#     duracion_minutos                                              album  \
# 0           3.119533           Young Miko: Bzrp Music Sessions, Vol. 58
# 1           2.809900                                        Manos Rotas
# 2           3.280000                                     FERXXOCALIPSIS
# 3           3.067117                                                111
# 4           4.200667                              No Te Quieren Conmigo
# 5           4.063433                                           Casanova
# 6           4.064967                      Una Foto Remix (feat. Emilia)
# 7           2.903817                     LVEU: VIVE LA TUYA...NO LA MIA
# 8           3.100000                                           Columbia
# 9           3.605633                                          Sol María
# 10          2.712783                nadie sabe lo que va a pasar mañana
# 11          2.343750                                               .mp3
# 12          3.174933                                            PARAÍSO
# 13          3.284200                                      PLAYA SATURNO
# 14          3.372667                     LVEU: VIVE LA TUYA...NO LA MIA
# 15          2.820133                                              A 300
# 16          3.745417                               COSAS QUE NO TE DIJE
# 17          2.654217                                            La Joia
# 18          3.067683                                        Si No Estás
# 19          2.899850                      Narcotics (with Bryant Myers)
# 20          3.494250                                          Sol María
# 21          2.878783                                        Madrid City
# 22          3.531317                                           ESTRELLA
# 23          2.704067                                    Quien Es Dei V?
# 24          2.879950                MAÑANA SERÁ BONITO (BICHOTA SEASON)
# 25          3.920000                                                 OA
# 26          4.800000                                    POLARIS (Remix)
# 27          3.707683                                      PLAYA SATURNO
# 28          4.133400  Japoni (feat. Camin, Moncho Chavea, Jthyago & ...
# 29          3.215900                                             Buenas
# 30          3.305867                                              STORM
# 31          2.541667                                            SI SABE
# 32          3.298667                                     LA VIDA ES UNA
# 33          2.710617                                               2000
# 34          3.593333                                          VAGABUNDO
# 35          3.861550                                            Holanda
# 36          3.174600                nadie sabe lo que va a pasar mañana
# 37          2.868250                                     ASI ES LA VIDA
# 38          2.164083                                           El Mambo
# 39          3.141400        LES DERNIÈRES VOLONTÉS DE MOZART (SYMPHONY)
# 40          2.926433                                          X'CLUSIVO
# 41          2.183667                                      lady madrizZz
# 42          3.188667                                           El Cielo
# 43          5.806667                                 Corazón Roto pt. 3
# 44          3.285233                                             Alucin
# 45          2.738217                    MOR, No Le Temas a La Oscuridad
# 46          3.393933                                               .mp3
# 47          5.633333                                    Los del Espacio
# 48          1.944433                               Saliendo del Planeta
# 49          4.472000                    No Estuviste En Lo Malo (REMIX)
#
#     explicito
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# 8       False
# 9       False
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 15      False
# 16      False
# 17       True
# 18      False
# 19       True
# 20      False
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28      False
# 29      False
# 30      False
# 31       True
# 32       True
# 33      False
# 34      False
# 35       True
# 36       True
# 37      False
# 38      False
# 39      False
# 40       True
# 41      False
# 42       True
# 43       True
# 44       True
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
